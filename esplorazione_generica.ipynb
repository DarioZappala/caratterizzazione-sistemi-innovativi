# %%
import numpy as np
import pandas as pd

path_data = '/Users/dariozappala/Library/CloudStorage/Dropbox/università/RTD-A/progetti/dati/Crunchbase/'

# %% [markdown]
# Interessanti:
# - Category groups
# - Jobs

# %% [markdown]
# # Acquisitions
# Acquisizioni delle compagnie

# %%
df_acquisitions = pd.read_csv(path_data + 'acquisitions.csv')
df_acquisitions.shape
# Out:
# (154338, 27)

# %%
df_acquisitions.iloc[:5, 0:15]
# Out:
#                                    uuid  \
# 0  c62807f2-3487-f63b-e7fc-559b752ed44c
# 1  419cabe1-4d71-5f64-3e9b-c9d0fb445cca
# 2  01bd2058-ccf8-6102-f253-9224a67a592b
# 3  831becd6-e913-b9f5-ac09-2bff915f9453
# 4  9da90ee7-aad7-e0b4-8456-839363032e5e
#
#                                         name         type  \
# 0  Flektor acquired by Fox Interactive Media  acquisition
# 1            GrandCentral acquired by Google  acquisition
# 2      Last.fm acquired by CBS Entertainment  acquisition
# 3              FeedBurner acquired by Google  acquisition
# 4    Recipezaar acquired by Scripps Networks  acquisition
#
#                                            permalink  \
# 0   fox-interactive-media-acquires-flektor--c62807f2
# 1             google-acquires-grandcentral--419cabe1
# 2                     cbs-acquires-last-fm--01bd2058
# 3               google-acquires-feedburner--831becd6
# 4  scripps-networks-interactive-acquires-recipeza...
#
# ...

# %%
df_acquisitions.iloc[:5, 15:27]
# Out:
#                           acquirer_uuid          acquirer_name  \
# 0  d70777cc-14bd-2416-0692-5a483781b78b  Fox Interactive Media
# 1  6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# 2  f09c1228-2e7d-1889-6647-ba5021b2e4ea      CBS Entertainment
# 3  6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# 4  b5a96cd7-044d-70f0-04c5-f125e57a4b35       Scripps Networks
#
#                                      acquirer_cb_url acquirer_country_code  \
# 0  https://www.crunchbase.com/organization/fox-in...                   USA
# 1     https://www.crunchbase.com/organization/google                   USA
# 2        https://www.crunchbase.com/organization/cbs                   USA
# 3     https://www.crunchbase.com/organization/google                   USA
# 4  https://www.crunchbase.com/organization/scripp...                   USA
#
#   acquirer_state_code acquirer_region  acquirer_city acquisition_type  \
# ...

# %% [markdown]
# # Category groups
# Settori di mercato e relativi gruppi

# %%
df_category_groups = pd.read_csv(path_data + 'category_groups.csv')
df_category_groups.shape
# Out:
# (744, 9)

# %%
df_category_groups
# Out:
#                                      uuid                      name      type  \
# 0    f9b14a15-5517-8f38-0562-729ebb54dfdb          Homeless Shelter  category
# 1    f8320fcf-b657-37d2-1495-daa3ad888ece                  Freemium  category
# 2    f0193199-a968-b457-eb49-95344e22a5ce                Industrial  category
# 3    ed8217ff-bd11-26fe-d82e-eb98a276dc2e     Innovation Management  category
# 4    e9794581-9547-2150-8185-7b747f5c9913                  Lighting  category
# ..                                    ...                       ...       ...
# 739  68413bd1-e42d-4cf1-815b-62e64a6b922a         Quantum Computing  category
# 740  3e0e2772-75e9-4f7b-aa6d-a8dc3dc9e7c6         Marine Technology  category
# 741  ce11fd97-65a0-4f8c-b385-2ca48f444479              Smart Cities  category
# 742  b561fa84-cb20-4a82-a6bc-fea613d74cdd  Last Mile Transportation  category
# 743  3fb898d3-4b96-418e-a58e-eaff8295e182                Legal Tech  category
#
#                     permalink  \
# ...

# %%
(df_category_groups.value_counts(['category_groups_list'], sort = True, normalize = False))[:20]
# Out:
# category_groups_list
# Other                                             33
# Transportation                                    29
# Health Care                                       29
# Sports                                            26
# Commerce and Shopping                             25
# Software                                          24
# Community and Lifestyle                           22
# Real Estate                                       22
# Food and Beverage                                 22
# Sales and Marketing                               21
# Professional Services                             19
# Financial Services                                18
# Hardware                                          17
# Internet Services                                 16
# Education                                         14
# Administrative Services                           14
# Financial Services,Lending and Investments        14
# ...

# %%
df_category_groups.value_counts(['name'], sort = False, normalize = False)
# Out:
# name
# 3D Printing      1
# 3D Technology    1
# A/B Testing      1
# Accounting       1
# Ad Exchange      1
#                 ..
# Young Adults     1
# eSports          1
# iOS              1
# mHealth          1
# macOS            1
# Name: count, Length: 744, dtype: int64

# %%
i = 100
df_category_groups[['category_groups_list', 'name']].sort_values(['category_groups_list', 'name'], ignore_index = True)[i:(i+10)]
# Out:
#         category_groups_list          name
# 100  Community and Lifestyle          Baby
# 101  Community and Lifestyle      Children
# 102  Community and Lifestyle   Communities
# 103  Community and Lifestyle        Dating
# 104  Community and Lifestyle       Elderly
# 105  Community and Lifestyle        Family
# 106  Community and Lifestyle  Humanitarian
# 107  Community and Lifestyle       Leisure
# 108  Community and Lifestyle     Lifestyle
# 109  Community and Lifestyle         Men's

# %% [markdown]
# # Degrees
# Titoli di studio e persone

# %%
df_degrees = pd.read_csv(path_data + 'degrees.csv')
df_degrees.shape
# Out:
# (835794, 17)

# %%
df_degrees
# Out:
#                                         uuid  \
# 0       205fdfd1-ecac-aa43-262f-219f11755f67
# 1       1a2ac288-eb99-3318-fde5-1517bc168f51
# 2       b978d338-7ccc-7469-5ce7-ef98c34155ad
# 3       d01cfaad-0ccc-631e-0382-1e507bf6ba04
# 4       16a607f5-8ab3-573e-8d09-57b3e352e1d3
# ...                                      ...
# 835789  439db8df-4d1a-4a50-a6e1-c6aa6fd9b2a0
# 835790  f4129153-b84f-4bd9-a655-ce359419aa23
# 835791  d489afb1-a065-4fe2-8d63-a43b002e4131
# 835792  6528b5c2-a2be-474c-9711-3d8ec348800c
# 835793  3fa2e61d-a734-4184-bd33-75fe0ebfdf96
#
#                                                      name    type  permalink  \
# 0              MS  Mass Communication @ Boston University  degree        NaN
# 1       BA  English, French @ Washington University in...  degree        NaN
# 2       MS  Internet Technology @ University of Greenwich  degree        NaN
# 3          BS  Computer Science @ Northeastern University  degree        NaN
# ...

# %% [markdown]
# # Event appearances
# Partecipazione delle compagnie a eventi

# %%
df_event_appearances = pd.read_csv(path_data + 'event_appearances.csv')
df_event_appearances.shape
# Out:
# (439128, 15)

# %%
df_event_appearances
# Out:
#                                         uuid  \
# 0       30c4023d-b694-4704-97d7-cd99cd06ecce
# 1       dffe0542-3dac-4228-a997-3eed42cbd67e
# 2       21884e6c-d097-4c54-8513-10536a0ea60d
# 3       c3782f8f-4684-47d6-8649-d0b3e1825eb5
# 4       55e2ee8b-b5b7-49d3-bd21-a63eedf6b7f2
# ...                                      ...
# 439123  5b21b238-3888-4951-9fea-9662a9923753
# 439124  57fbe993-7e9f-471f-94f4-cd0480ad2345
# 439125  4772ab90-bfa8-4847-853d-67a70bbe2420
# 439126  3e3551ee-fa11-4aa1-88aa-2637b789fad1
# 439127  4b496097-0746-4a50-9289-1d771b729e00
#
#                                                      name              type  \
# 0              Adobe MAX 2014's sponsor - CDW Corporation  event_appearance
# 1                    Adobe MAX 2014's sponsor - Microsoft  event_appearance
# 2         Adobe MAX 2014's sponsor - X (formerly Twitter)  event_appearance
# 3                           Adobe MAX 2014's sponsor - HP  event_appearance
# ...

# %% [markdown]
# # Events

# %%
df_events = pd.read_csv(path_data + 'events.csv')
df_events.shape
# Out:
# (28720, 21)

# %%
df_events.iloc[:5, 0:10]
# Out:
#                                    uuid              name   type  \
# 0  6a21f93a-3cae-02ac-44c7-c166c0ed50fa       SF New Tech  event
# 1  135a927a-b238-037e-50e2-d3a2e3511ed2    Adobe MAX 2014  event
# 2  c6006d9f-e796-2a2a-2efc-c4e55caa98f8  ad:tech New York  event
# 3  2710319a-f022-5cd3-f855-6594fd0d6db3   Engadget Expand  event
# 4  35e61ac8-58bf-0492-8285-39dc9c2b236d   Dreamforce 2014  event
#
#                            permalink  \
# 0          sfnt-201272-san-francisco
# 1      adobe-max-2014104-los-angeles
# 2  ad-tech-new-york-2014105-new-york
# 3   engadget-expand-2014107-new-york
# 4  dreamforce-20141013-san-francisco
#
#                                               cb_url     rank  \
# 0  https://www.crunchbase.com/event/sfnt-201272-s...   4593.0
# 1  https://www.crunchbase.com/event/adobe-max-201...  26222.0
# 2  https://www.crunchbase.com/event/ad-tech-new-y...  25273.0
# 3  https://www.crunchbase.com/event/engadget-expa...  14788.0
# ...

# %%
df_events.iloc[:5, 10:21]
# Out:
#      ended_on                                          event_url  \
# 0  2014-10-14                                                NaN
# 1  2014-10-08                                                NaN
# 2  2014-10-06                                                NaN
# 3  2014-11-08                                                NaN
# 4  2014-10-16  https://www.montypythonlive.com/best-led-grow-...
#
#                                     registration_url  \
# 0              http://1015sfnt-meetup.eventbrite.com
# 1                 http://max.adobe.com/registration/
# 2                 http://ad-tech.com/ny/registration
# 3  http://www.eventbrite.com/e/engadget-expand-ny...
# 4  http://www.salesforce.com/dreamforce/DF14/regi...
#
#                       venue_name  \
# 0                  RocketStudios
# 1  Los Angeles Convention Center
# 2                  Javits Center
# 3                  Javits Center
# 4                 Moscone Center
#
# ...

# %% [markdown]
# # Funding rounds
# Investimenti da parte di una compagnia in un'altra compagnia?

# %%
df_funding_rounds = pd.read_csv(path_data + 'funding_rounds.csv')
df_funding_rounds.shape
# Out:
# (593382, 24)

# %%
df_funding_rounds.iloc[:5, 0:12]
# Out:
#                                    uuid                    name  \
# 0  8a945939-18e0-cc9d-27b9-bf33817b2818      Angel Round - Meta
# 1  d950d7a5-79ff-fb93-ca87-13386b0e2feb         Series A - Meta
# 2  6fae3958-a001-27c0-fb7e-666266aedd78         Series B - Meta
# 3  bcd5a63d-ed99-6963-0dd2-e36f6582f846  Series B - Photobucket
# 4  60e6afd9-1215-465a-dd17-0ed600d4e29b         Series A - Geni
#
#             type                       permalink  \
# 0  funding_round        facebook-angel--8a945939
# 1  funding_round     facebook-series-a--d950d7a5
# 2  funding_round     facebook-series-b--6fae3958
# 3  funding_round  photobucket-series-b--bcd5a63d
# 4  funding_round         geni-series-a--60e6afd9
#
#                                               cb_url      rank  \
# 0  https://www.crunchbase.com/funding_round/faceb...  560707.0
# 1  https://www.crunchbase.com/funding_round/faceb...  366132.0
# 2  https://www.crunchbase.com/funding_round/faceb...  454468.0
# ...

# %%
df_funding_rounds.iloc[:5, 12:24]
# Out:
#   investment_type announced_on  raised_amount_usd  raised_amount  \
# 0           angel   2004-09-01           500000.0       500000.0
# 1        series_a   2005-05-01         12700000.0     12700000.0
# 2        series_b   2006-04-01         27500000.0     27500000.0
# 3        series_b   2006-05-01         10500000.0     10500000.0
# 4        series_a   2007-01-17                NaN            NaN
#
#   raised_amount_currency_code  post_money_valuation_usd  post_money_valuation  \
# 0                         USD                       NaN                   NaN
# 1                         USD                98000000.0            98000000.0
# 2                         USD               502500000.0           502500000.0
# 3                         USD                       NaN                   NaN
# 4                         NaN                10000000.0            10000000.0
#
#   post_money_valuation_currency_code  investor_count  \
# ...

# %% [markdown]
# # Funds
# Investimenti?

# %%
df_funds = pd.read_csv(path_data + 'funds.csv')
df_funds.shape
# Out:
# (22970, 15)

# %%
df_funds
# Out:
#                                        uuid  \
# 0      8190b28a-3c78-0ac4-1e7c-f0b5edce4b2e
# 1      cbb6644a-eafb-4686-5505-61f32e1c3638
# 2      19fa5c4f-23c3-8c03-2b37-bcd0334505c9
# 3      e803081d-0974-eda7-ab5f-c0f1a0a432fe
# 4      49a5722a-084c-3466-fd90-37e885c800b1
# ...                                     ...
# 22965  361b7f9a-66bc-43d6-a00b-3d8ed28b4ad7
# 22966  ae51914c-23b3-4303-a103-1cbbe259e001
# 22967  2f243fcb-19d1-4b62-b204-cc0009075bfc
# 22968  3e819e6e-b753-405a-a094-d753d84e10e2
# 22969  afadbb58-d941-46b4-8227-607d0cf0843a
#
#                                           name  type  \
# 0                       DFJ Dragon Second Fund  fund
# 1                       Sequoia Israel Fund IV  fund
# 2                         InterWest Tenth Fund  fund
# 3                      U.S. Venture Partners X  fund
# 4          Inventus Capital Partners Fund I LP  fund
# ...                                        ...   ...
# 22965  Redstone Schwarzwälder Bote Beteiligung  fund
# ...

# %% [markdown]
# # Investment partners

# %%
df_investment_partners = pd.read_csv(path_data + 'investment_partners.csv')
df_investment_partners.shape
# Out:
# (210712, 14)

# %%
df_investment_partners
# Out:
#                                         uuid  \
# 0       524986f0-3049-54a4-fa72-f60897a5e61d
# 1       524986f0-3049-54a4-fa72-f60897a5e61d
# 2       6556ab92-6465-25aa-1ffc-7f8b4b09a476
# 3       0216e06a-61f8-9cf1-19ba-20811229c53e
# 4       dadd7d86-520d-5e35-3033-fc1d8792ab91
# ...                                      ...
# 210707  618f3444-456a-4020-8469-0b41411643ab
# 210708  3970d6c5-8f30-4d63-baa4-d001adc47120
# 210709  cb33bb13-81ff-4599-8b49-142b97c97dee
# 210710  8017381d-a5f8-4e3c-8224-b2d46236595f
# 210711  8017381d-a5f8-4e3c-8224-b2d46236595f
#
#                                                      name        type  \
# 0                     Accel investment in Series A - Meta  investment
# 1                     Accel investment in Series A - Meta  investment
# 2                  Greylock investment in Series B - Meta  investment
# 3       Meritech Capital Partners investment in Series...  investment
# ...

# %% [markdown]
# # Investments

# %%
df_investments = pd.read_csv(path_data + 'investments.csv')
df_investments.shape
# Out:
# (961604, 14)

# %%
df_investments
# Out:
#                                         uuid  \
# 0       524986f0-3049-54a4-fa72-f60897a5e61d
# 1       6556ab92-6465-25aa-1ffc-7f8b4b09a476
# 2       0216e06a-61f8-9cf1-19ba-20811229c53e
# 3       dadd7d86-520d-5e35-3033-fc1d8792ab91
# 4       581c4b38-9653-7117-9bd4-7ffe5c7eba69
# ...                                      ...
# 961599  1e819c0e-13bc-414a-8182-b1a71743ec57
# 961600  15795953-5414-402e-ab4f-ec9841f1dcc0
# 961601  484a0a22-a884-4ce9-8bda-c6a5b60b23b4
# 961602  0d33ccbc-7f87-4faa-b35b-20593de81c8b
# 961603  8017381d-a5f8-4e3c-8224-b2d46236595f
#
#                                                      name        type  \
# 0                     Accel investment in Series A - Meta  investment
# 1                  Greylock investment in Series B - Meta  investment
# 2       Meritech Capital Partners investment in Series...  investment
# 3       Trinity Ventures investment in Series B - Phot...  investment
# ...

# %% [markdown]
# # Investors

# %%
df_investors = pd.read_csv(path_data + 'investors.csv')
df_investors.shape
# Out:
# (261125, 25)

# %%
df_investors.iloc[:5, 0:12]
# Out:
#                                    uuid             name          type  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71      Ben Elowitz        person
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 3  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
# 4  a01b8d46-d311-3333-7c34-aa3ae9c03f22  Mark Zuckerberg        person
#
#          permalink                                             cb_url  \
# 0      ben-elowitz      https://www.crunchbase.com/person/ben-elowitz
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 3         facebook   https://www.crunchbase.com/organization/facebook
# 4  mark-zuckerberg  https://www.crunchbase.com/person/mark-zuckerberg
#
#        rank           created_at           updated_at             roles  \
# ...

# %%
df_investors.iloc[:5, 12:25]
# Out:
#        region          city            investor_types  investment_count  \
# 0  Washington       Seattle                     angel               2.0
# 1  California    Pleasanton                       NaN               9.0
# 2  California  Redwood City  family_investment_office             343.0
# 3  California    Menlo Park                       NaN              54.0
# 4  California     Palo Alto  investment_partner,angel               8.0
#
#    total_funding_usd  total_funding total_funding_currency_code  founded_on  \
# 0                NaN            NaN                         NaN         NaN
# 1                NaN            NaN                         NaN  1996-03-17
# 2                NaN            NaN                         NaN  2004-01-01
# 3       2.462282e+10   2.462282e+10                         USD  2004-02-04
# 4                NaN            NaN                         NaN         NaN
#
#   closed_on                            facebook_url  \
# ...

# %% [markdown]
# # Ipos

# %%
df_ipos = pd.read_csv(path_data + 'ipos.csv')
df_ipos.shape
# Out:
# (49427, 27)

# %%
df_ipos.iloc[:5, 0:12]
# Out:
#                                    uuid  name type  \
# 0  72d30ebd-53ef-2486-6c29-22785c5173ce   NaN  ipo
# 1  3ad2b068-2d97-f646-0b80-1e5f3d7adfc4   NaN  ipo
# 2  a265c6f6-4b96-4079-096a-967a37f3da2b   NaN  ipo
# 3  ee426509-826e-5dd0-9309-e79c8f384904   NaN  ipo
# 4  66b57372-77f0-ec5f-ca33-0175fff79b0e   NaN  ipo
#
#                                permalink  \
# 0                microsoft-ipo--72d30ebd
# 1  the-walt-disney-company-ipo--3ad2b068
# 2                     divx-ipo--a265c6f6
# 3                 xo-group-ipo--ee426509
# 4             bmc-software-ipo--66b57372
#
#                                               cb_url   rank  \
# 0  https://www.crunchbase.com/ipo/microsoft-ipo--...  37817
# 1  https://www.crunchbase.com/ipo/the-walt-disney...  16641
# 2  https://www.crunchbase.com/ipo/divx-ipo--a265c6f6   3163
# 3  https://www.crunchbase.com/ipo/xo-group-ipo--e...  26682
# 4  https://www.crunchbase.com/ipo/bmc-software-ip...  26986
#
# ...

# %%
df_ipos.iloc[:5, 12:25]
# Out:
#   state_code      region       city stock_exchange_symbol stock_symbol  \
# 0         WA  Washington    Redmond                nasdaq         MSFT
# 1         CA  California    Burbank                  nyse          DIS
# 2         CA  California  San Diego                nasdaq         DIVX
# 3         NY    New York   New York                  nyse         XOXO
# 4         TX       Texas    Houston                nasdaq          BMC
#
#   went_public_on  share_price_usd  share_price share_price_currency_code  \
# 0     1986-03-13              NaN          NaN                       NaN
# 1     1978-01-13              NaN          NaN                       NaN
# 2     2006-10-22             16.0         16.0                       USD
# 3     1999-12-02              NaN          NaN                       NaN
# 4     1988-08-12              NaN          NaN                       NaN
#
#    valuation_price_usd  valuation_price valuation_price_currency_code  \
# ...

# %% [markdown]
# # Jobs
#
# - `title` indica il ruolo dettagliato
# - `job_type` indica la categoria generale del ruolo. Può avere 5 valori:
#     - `executive` (1.869.260): Circa 723.000 ruoli con la parola 'founder'. Per il resto, ruoli dirigenziali.
#     - `employee` (626.450): Ruoli vari. Circa 18.000 ruoli con la parola 'founder'.
#     - `board_member` (218.030): Vari ruoli con 'member' e 'board'. Circa 8000 ruoli con 'founder'.
#     - `advisor` (84.071): Quasi tutti ruoli con la parola 'advisor'. Circa 2000 'Mentor' e 1000 'founder'
#     - `board_observer` (8855)

# %%
df_jobs = pd.read_csv(path_data + 'jobs.csv')
df_jobs.shape
# Out:
# (2806666, 17)

# %%
df_jobs
# Out:
#                                          uuid  \
# 0        697b6934-fc1f-9d63-cfb2-1a10759b378e
# 1        b1de3765-442e-b556-9304-551c2a055901
# 2        1319cd30-f5e8-c700-0af6-64029c6f7124
# 3        27a252de-1ea8-c620-b2d4-5b889fa9b40f
# 4        5a802a79-229f-44ae-0aba-db330f10b67a
# ...                                       ...
# 2806661  14d5c449-fecb-41de-95de-10c27de1f3f8
# 2806662  93f0ff7c-64d8-4642-a8a8-9e85d702f3c8
# 2806663  f103bcc8-4575-4acc-8ccc-055d01b656e1
# 2806664  8562ba83-fac6-4a59-bb3a-847ce5063fa6
# 2806665  011b627c-c039-48d6-b816-ff43e0883ebc
#
#                                                       name type  \
# 0                Ben Elowitz Co-Founder and CEO @ Wetpaint  job
# 1                   Kevin Flaherty VP Marketing @ Wetpaint  job
# 2                     Raju Vegesna Chief Evangelist @ Zoho  job
# 3                 Ian Wenig VP Business Development @ Zoho  job
# 4                                   Jay Adelson CEO @ Digg  job
# ...

# %%
(df_jobs.value_counts(['job_type'], sort = True, normalize = False, dropna = False))[:20]
# Out:
# job_type
# executive         1869260
# employee           626450
# board_member       218030
# advisor             84071
# board_observer       8855
# dtype: int64

# %%
df_jobs_clean = df_jobs[['job_type', 'title']].copy()

# %%
df_jobs_clean.loc[
    df_jobs_clean['title'].str.contains('founder', case = False, na = False),
    'title'
] = 'Founder'

# %%
stats = pd.DataFrame(
    df_jobs_clean.value_counts(['job_type', 'title'], sort = True, normalize = False, dropna = False),
    columns = ['counts']
).reset_index()

# %%
i = 0
stats[stats['job_type'] == 'board_observer'].iloc[i:(i+20)]
#stats[stats['title'].str.contains('mentor', case = False, na = False)].iloc[i:(i+20)]
#stats[(stats['job_type'] == 'employee') & (stats['title'].str.contains('founder', case = False, na = False))].iloc[i:(i+20)]
# Out:
#             job_type                                      title  counts
# 30    board_observer                             Board Observer    5983
# 385   board_observer            Member of the Board of Observer     376
# 618   board_observer                                   Observer     222
# 642   board_observer                                   Investor     210
# 961   board_observer                             Board observer     135
# 1017  board_observer                                    Founder     126
# 1192  board_observer                                    Advisor     106
# 1619  board_observer               Member of the Board Observer      70
# 1688  board_observer                               Board Member      68
# 1793  board_observer                Investor and Board Observer      63
# 2006  board_observer                  Investor & Board Observer      55
# 2091  board_observer                   Investor, Board Observer      53
# ...

# %%
stats.shape
# Out:
# (595715, 3)

# %% [markdown]
# # Org parents
# Compagnie madri?

# %%
df_org_parents = pd.read_csv(path_data + 'org_parents.csv')
df_org_parents.shape
# Out:
# (25444, 10)

# %%
df_org_parents
# Out:
#                                        uuid  \
# 0      d70777cc-14bd-2416-0692-5a483781b78b
# 1      3d9e4070-1a25-7491-d1a9-17bec9f6361b
# 2      f09c1228-2e7d-1889-6647-ba5021b2e4ea
# 3      91f5ca18-e026-9482-8e4f-22593943e0f5
# 4      e0906c05-fae5-9591-ba5f-2142d8b0065a
# ...                                     ...
# 25439  fcc5dfed-2981-4bde-9d7e-fbc7d8b8f5e7
# 25440  5b394181-ce3f-49a0-b8b6-62836a72ad3c
# 25441  56104b89-7afd-44c9-ba6f-0db1c011fdb5
# 25442  6a2ca961-f677-4768-89c3-3c5c61073ad4
# 25443  58741817-d605-4e4d-9bb4-3b593903cecc
#
#                                              name          type  \
# 0                           Fox Interactive Media  organization
# 1                               Hutchison Whampoa  organization
# 2                               CBS Entertainment  organization
# 3                                           Plaxo  organization
# 4                                           Cisco  organization
# ...

# %% [markdown]
# # Organization descriptions

# %%
df_organization_descriptions = pd.read_csv(path_data + 'organization_descriptions.csv')
df_organization_descriptions.shape
# Out:
# (1361024, 9)

# %%
df_organization_descriptions
# Out:
#                                          uuid                name  \
# 0        e1393508-30ea-8a36-3f96-dd3226033abd            Wetpaint
# 1        bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                Zoho
# 2        5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                Digg
# 3        f4d5ab44-058b-298b-ea81-380e6e9a8eec     Omidyar Network
# 4        df662812-7f97-0b43-9d3e-12f64f504fbb                Meta
# ...                                       ...                 ...
# 1361019  44214125-8e8f-41c8-a7f9-c559533fe0bd           Clurebyte
# 1361020  dcaf9883-8e32-434c-98e4-b3c8025348fa      CloudStudio AI
# 1361021  faccccb3-1dde-48a5-b8d8-ad65714543b0           Homegrown
# 1361022  d1aa44bf-2455-4e4c-bb25-ece078bd35b6  Bitcoin Investment
# 1361023  dbd9d572-8629-433b-ab52-dd06c6270a7c              Trocah
#
#                  type            permalink  \
# 0        organization             wetpaint
# 1        organization                 zoho
# ...

# %% [markdown]
# # Organizations

# %%
df_organizations = pd.read_csv(path_data + 'organizations.csv')
df_organizations.shape
# Out:
# (3090736, 41)

# %%
df_organizations.iloc[:5, 0:20]
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
#
#          permalink                                             cb_url  \
# 0         wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2             digg       https://www.crunchbase.com/organization/digg
# 3  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4         facebook   https://www.crunchbase.com/organization/facebook
#
#        rank           created_at           updated_at  \
# 0  184663.0  2007-05-25 13:51:27  2023-08-01 00:01:37
# ...

# %%
df_organizations.iloc[:5, 20:40]
# Out:
#                                        category_list  \
# 0    Publishing,Social Media,Social Media Management
# 1  Cloud Computing,Collaboration,Developer Tools,...
# 2               Internet,Social Media,Social Network
# 3  Enterprise Software,Financial Services,Venture...
# 4  Augmented Reality,Social Media,Social Network,...
#
#                                 category_groups_list  num_funding_rounds  \
# 0  Content and Publishing,Internet Services,Media...                 3.0
# 1  Administrative Services,Apps,Information Techn...                 NaN
# 2          Internet Services,Media and Entertainment                 6.0
# 3  Financial Services,Lending and Investments,Sof...                 NaN
# 4  Hardware,Internet Services,Media and Entertain...                16.0
#
#    total_funding_usd  total_funding total_funding_currency_code  founded_on  \
# 0       3.975000e+07   3.975000e+07                         USD  2005-06-01
# ...

# %%
df_organizations.iloc[:5, 36:41]
# Out:
#      alias1          alias2 alias3 primary_role  num_exits
# 0       NaN             NaN    NaN      company        NaN
# 1       NaN             NaN    NaN      company        2.0
# 2       NaN             NaN    NaN      company        NaN
# 3       NaN             NaN    NaN     investor       59.0
# 4  Facebook  Facebook, Inc.    NaN      company        1.0

# %% [markdown]
# # People descriptions

# %%
df_people_descriptions = pd.read_csv(path_data + 'people_descriptions.csv')
df_people_descriptions.shape
# Out:
# (1223380, 9)

# %%
df_people_descriptions
# Out:
#                                          uuid  \
# 0        ed13cd36-fe2b-3707-197b-0c2d56e37a71
# 1        5ceca97b-493c-1446-6249-5aaa33464763
# 2        9f99a98a-aa97-b30b-0d36-db67c1d277e0
# 3        6e1bca72-a865-b518-b305-31214ce2d1b0
# 4        3b598c59-7b6c-2d48-763c-da55bca77035
# ...                                       ...
# 1223375  d85e1c1e-e60f-43ea-a7e5-9aaead822891
# 1223376  5d31e207-1391-4741-8d5b-0c39b1606491
# 1223377  157d8449-bd26-4196-a1b8-d60bab080bd7
# 1223378  1f691594-24ec-4a97-aa82-be0846334271
# 1223379  abda4b12-3bc7-4f60-8160-8c39b366b1cb
#
#                                        name    type  \
# 0                               Ben Elowitz  person
# 1                            Kevin Flaherty  person
# 2                              Raju Vegesna  person
# 3                                 Ian Wenig  person
# 4                                Owen Byrne  person
# ...                                     ...     ...
# ...

# %% [markdown]
# # People

# %%
df_people = pd.read_csv(path_data + 'people.csv')
df_people.shape
# Out:
# (1785506, 22)

# %%
df_people
# Out:
#                                          uuid  \
# 0        ed13cd36-fe2b-3707-197b-0c2d56e37a71
# 1        5ceca97b-493c-1446-6249-5aaa33464763
# 2        9f99a98a-aa97-b30b-0d36-db67c1d277e0
# 3        6e1bca72-a865-b518-b305-31214ce2d1b0
# 4        3b598c59-7b6c-2d48-763c-da55bca77035
# ...                                       ...
# 1785501  3d627557-af50-487a-a4c0-153e79706c1f
# 1785502  abda4b12-3bc7-4f60-8160-8c39b366b1cb
# 1785503  c4ce3f4b-b5e5-416d-abe1-bc8bda470e3d
# 1785504  558c69d6-352d-4dc7-83cb-1047095c3ffe
# 1785505  39189e61-041a-44ae-b571-a5b0295732b1
#
#                                        name    type  \
# 0                               Ben Elowitz  person
# 1                            Kevin Flaherty  person
# 2                              Raju Vegesna  person
# 3                                 Ian Wenig  person
# 4                                Owen Byrne  person
# ...                                     ...     ...
# ...
